# %%
import os

path="/home/azureuser/env/test/segan_pytorch/noisefile0817/short16/"

#os.mkdir("/home/azureuser/env/test/segan_pytorch/noisefile0817/newshort16/")

# %%
import shutil
import soundfile as sf
for item in os.listdir(path):
    #print(item)
    data , sr = sf.read(path + item)
    print(data)
    sf.write("/home/azureuser/env/test/segan_pytorch/noisefile0817/newshort16/" + item ,data , sr, subtype='PCM_16')
# Out:
# [-0.00664146 -0.00743591 -0.00609752 ...  0.09501167  0.07844162
#   0.03932823]
# [0.00106253 0.00083074 0.00058488 ... 0.00251361 0.00176887 0.00079776]
# [-1.76093381e-04 -8.24263552e-05  1.15038725e-04 ...  1.72416330e-05
#   8.15309249e-05  6.63049286e-05]
# [ 1.91831481e-04  2.27521174e-04  1.43281271e-04 ... -2.72924837e-04
#  -2.05793622e-04 -9.87584572e-05]
# [4.17380885e-04 3.20022838e-04 9.44193380e-06 ... 1.54992088e-03
#  7.86757737e-04 2.45348725e-04]
# [-0.00021507 -0.00022318 -0.00015093 ... -0.00068945 -0.00081905
#  -0.00048128]
# [-1.10842520e-04  3.72809154e-05 -1.54499881e-04 ... -1.33690005e-03
#   3.39583959e-04  1.11512328e-03]
# [-0.00023486 -0.00029328 -0.00036008 ... -0.00277238 -0.00276409
#  -0.00152305]
# [ 2.15238426e-03  2.19104602e-03  1.13199314e-03 ... -1.42548431e-03
#  -8.54204118e-05  3.69474874e-04]
# [-0.00173168 -0.00203573 -0.0016095  ... -0.03934292 -0.03392575
#  -0.01743252]
# ...
